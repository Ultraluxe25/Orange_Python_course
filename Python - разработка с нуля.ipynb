# %% [markdown]
# ![image.png](attachment:f0cfd2a8-1164-4dd7-a10a-ace833df981f.png)

# %%
import sys

sys.version
# Out:
# '3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]'

# %% [markdown]
# ![image.png](attachment:feb41b97-c527-4bff-be41-28671499bf2b.png)

# %% [markdown]
# ![image.png](attachment:19ca8922-b0ae-495b-b9b1-c7389259b16f.png)

# %% [markdown]
# ![image.png](attachment:e57e419c-9434-4901-b60e-ba00566ac247.png)

# %%
# !pip install flask
# Out:
# ...
#   Using cached flask-3.0.2-py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# ...
# Using cached flask-3.0.2-py3-none-any.whl (101 kB)
# Using cached blinker-1.7.0-py3-none-any.whl (13 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# ...

# %% [markdown]
# ![image.png](attachment:861094a8-bb1d-4c11-8d4b-503e1cce601c.png)
#
# Это означает что Flask будет искать все файлы нашего сайта в этой папке

# %% [markdown]
# ![image.png](attachment:95964914-dacf-4e27-9510-25b11a445a8d.png)
#
# **debug==True** позволяет отображать все ошибки прямо на сайте (нужен на этапе разработки веб-приложения)

# %% [markdown]
# ![image.png](attachment:295df3e6-9945-4130-9338-c4e8f33d9f4c.png)
#
# Маршрутизация для групп, например user

# %% [markdown]
# ![image.png](attachment:7ee14aa8-0ab0-4dde-8180-2df5912d8193.png)
#
# **render_template** позволяет возвращать HTML-страницу по маршруту

# %% [markdown]
# # Внимание! Не запускайте приложение в нескольких IDE вроде PyCharm и VS Code!
# Пока одно в одном приложение запущено, изменения в другом не вступят в силу! Лучше работать только в PyCharm

# %% [markdown]
# **Jinja2** Позволяет в HTML использовать циклы, условные операторы и отдельные переменные из Python

# %% [markdown]
# ![image.png](attachment:a35ee6cd-d71f-4a48-a948-0d0dc242da0a.png)
#
# Подключаем SQLAlchemy чтобы управлять БД не с помощью SQL, а используя Python ООП.
#
# **app.config** - словарь зависимостей нашего проекта

# %% [markdown]
# ![image.png](attachment:8a15914d-b773-4434-ac5c-e5d0657dcd7a.png)
#
# Для создания экземпляра нашей базы данных нужно выполнить это в терминале. Экземпляр появится в папке **instance** нашего проекта

# %% [markdown]
# Для работы ссылок в url_for нужно указывать не название .html файлов, а название функций в которых они обрабатываются в app.py
